# %% [markdown]
# # **Multiple split-operator Fourier transform method (MSOFT)**
#
# <hr style="height:1px;border:none;color:#cccccc;background-color:#cccccc;" />
#
# <ol style="font-size:18px">
#     <li><a href="./msoft.ipynb">Numerical Solution of 1D Time Dependent Schrödinger Equation for a nuclear wavepacket moving on two electronic potential energy surfaces by the Multiple Split Operator Fourier Transform (MSOFT) Method.</a></li>
# </ol>
